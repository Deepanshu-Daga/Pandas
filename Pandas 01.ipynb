# %%
# ineuron pandas gives 2d structure data -- easy indexing

# %%
import os
import pandas as pd 
df = pd.read_csv("C:/Users/deepa/Downloads/archive/netflix.csv" , header = 0) 
                                                                # take address from properties of file or tab
                                                                # pandas can read everything json , excel , html , api, sql
                                                                # header = 0, None   decides the header line
                                                                # WE CAN USE diff separator by default in csv sep = ','

# %%
type(df)                                     # pandas creates a data frame : tabular data structure
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# data frame concept is similar in spark aslo
# Spark is a framework and set of libraries for parallel data processing. It was created in 2014 to address many of Apache Hadoop's shortcomings, and is much faster than Hadoop for analytic workloads because it stores data in-memory (RAM) rather than on disk.

# %%
df.head(10)                     #  head is an inbuilt fx to get 10 rows data
                  # data in pandas are by default indexed ( row and column) : notice 0 , 1 , 2 .. not in original data
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
# 6  For mature audiences.  May not be suitable for...                110
# ...

# %%
df.dtypes                                                #  datatypes of all attributes
# Out:
# title                 object
# rating                object
# ratingLevel           object
# ratingDescription      int64
# release year           int64
# user rating score    float64
# user rating size       int64
# dtype: object

# %%
df.tail()                                                # by default head() , tail() both give 5 records
# Out:
#                        title rating  \
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999                                                NaN                 35
#
#      release year  user rating score  user rating size
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# ...

# %%
# to get all ccolumn names
df.columns
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
# to get all values of any sinle column
df["rating"]
# Out:
# 0      PG-13
# 1          R
# 2      TV-14
# 3      TV-14
# 4      TV-PG
#        ...
# 995       PG
# 996       PG
# 997     TV-G
# 998     TV-G
# 999        G
# Name: rating, Length: 1000, dtype: object

# %%
                                           # list of data is series = [data] = series
type(df["rating"])                         # this time it is pandas series not dataframe
                                           # series is a 1 single record may it be row or column
# Out:
# pandas.core.series.Series

# %%
type(df[["rating"]])                       # list of series is data frame =[[data]] = [series]= dataframe
                                           # dataframe is 2d structured data
                                           # thus for multiple columns use list of list
# Out:
# pandas.core.frame.DataFrame

# %%
df[["rating"]]
# Out:
#     rating
# 0    PG-13
# 1        R
# 2    TV-14
# 3    TV-14
# 4    TV-PG
# ..     ...
# 995     PG
# 996     PG
# 997   TV-G
# 998   TV-G
# 999      G
#
# [1000 rows x 1 columns]

# %%
# thus for multiple columns use list of list 
df[["title"  , "rating"]]
# Out:
#                        title rating
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
# [1000 rows x 2 columns]

# %%
df1 = df.head(9)                                            # first 5 records in other dataframe
df1.to_json("jtest.json")                                   # saving dataframe data as json file

# %%
pwd()                                                       # for current directory address
# Out:
# 'C:\\Users\\deepa\\DATA SCIENCE\\Untitled Folder'

# %%
ls                                                          # we can see listdirectoty and json in it is created automaticaly
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is A07A-1E25
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
#
#
#  Directory of C:\Users\deepa\DATA SCIENCE\Untitled Folder
# File Not Found

# %%
pd.read_json("C:\\Users\\deepa\\DATA SCIENCE\\Untitled Folder\\jtest.json" )            # reading same json data
                                                                            # pandas while reading automatically indexes
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
# 6  For mature audiences.  May not be suitable for...                110
# ...

# %%
# here if we go and see in folder section file has index in it
df1.to_csv("111" )

# %%
# here if we go and see in folder section file does not have any index
df1.to_csv("111" , index="False" )

# %%
# This removes header as well as index from actual excle
# we can change default separator as well.
df1.to_csv("111", index = "False", header = "False" ,sep="#" )

# %%
# we can do analysis and save bare min relevent data of ur choice
# Go check in file
df1.to_csv("111", index = False , columns=["title", "rating"] )

# %%
## we can give coustomised names to columns 
# name = []   in list
#skiprows helps to skip specific rows skips index 1,3,4

pd.read_csv("C:/Users/deepa/Downloads/archive/netflix.csv" ,names = ["A", "B", "C","D","E","F","G","H"], header = None ,
            skiprows=[1,3,4])

# %%
# What does Na_values do in Python?
# na_values: This is used to create a string that considers selected values as NaN (Not a Number)
# used to control outlies 
# changes all values = [80,82]= NAN              multiple values in list

pd.read_csv("C:/Users/deepa/Downloads/archive/netflix.csv" , header = None , na_values= [80,82])
# Out:
#                             0       1  \
# 0                       title  rating
# 1                White Chicks   PG-13
# 2         Lucky Number Slevin       R
# 3              Grey's Anatomy   TV-14
# 4                Prison Break   TV-14
# ...                       ...     ...
# 996                   The BFG      PG
# 997   The Secret Life of Pets      PG
# 998          Precious Puppies    TV-G
# 999               Beary Tales    TV-G
# 1000          Growing Up Wild       G
#
#                                                       2                  3  \
# 0                                           ratingLevel  ratingDescription
# 1     crude and sexual humor, language and some drug...                NaN
# 2     strong violence, sexual content and adult lang...                100
# 3     Parents strongly cautioned. May be unsuitable ...                 90
# 4     Parents strongly cautioned. May be unsuitable ...                 90
# ...

# %%
pd.fx()     #  gives output as a dataframe

# %%
# all the reading part is doen in pandas 
# all the changing fx are done on dataframes df after reading by pandas

# %%
# html pages can also be read 
# reading money contol fii dii activity

# %%
#to get all the column names

df.columns
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
df2 = pd.read_html("https://www.moneycontrol.com/stocks/marketstats/fii_dii_activity/index.php" )

# %%
df2
# Out:
# [  Unnamed: 0_level_0  FII Rs Crores                                   \
#                  Date Gross Purchase Gross Sales Net Purchase / Sales
#  0    Month till date        61229.8     70942.4              -9712.6
#
#     DII Rs Crores
#    Gross Purchase Gross Sales Net Purchase / Sales
#  0       59636.31    53799.06              5837.25  ,
#           Unnamed: 0_level_0  FII Rs Crores                                   \
#                         Date Gross Purchase Gross Sales Net Purchase / Sales
#              Month till date      61,229.80   70,942.40            -9,712.60
#  0  11-Feb-2022  11-Feb-2022        9754.86     9646.33               108.53
#  1  10-Feb-2022  10-Feb-2022        8660.61    10393.19             -1732.58
#  2  09-Feb-2022  09-Feb-2022        6152.38     7045.02              -892.64
#  3  08-Feb-2022  08-Feb-2022        7225.08     9192.97             -1967.89
#  4  07-Feb-2022  07-Feb-2022        6281.52     7438.75             -1157.23
# ...

# %%
df
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
df.describe()

# describe gives  information about columns having int and float 
# thus we get 25th percentile position data index data after sorting the data
# similar to power bi  fast column quality check 
# this gives us a quick view of the quality of data , no of null , nan values ,
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000
